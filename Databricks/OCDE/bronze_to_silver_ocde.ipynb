# %%
###Establish account key G2
spark.conf.set("fs.azure.account.key.tfmgendos.dfs.core.windows.net","QT/ULR9KopMmUZmz55avGjsJf/cuoAdFd/HUT3qDxs5pLllRhvXwyQEsqn8b1RKn91hv7lTuhb9K+AStoUFp+A==")

basepath="abfss://tfm@tfmgendos.dfs.core.windows.net/"

dbutils.fs.ls(basepath)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: [FileInfo(path=&#39;abfss://tfm@tfmgendos.dfs.core.windows.net/bronze/&#39;, name=&#39;bronze/&#39;, size=0, modificationTime=1662129140000),
#  FileInfo(path=&#39;abfss://tfm@tfmgendos.dfs.core.windows.net/gold/&#39;, name=&#39;gold/&#39;, size=0, modificationTime=1662129150000),
#  FileInfo(path=&#39;abfss://tfm@tfmgendos.dfs.core.windows.net/landing/&#39;, name=&#39;landing/&#39;, size=0, modificationTime=1662129135000),
#  FileInfo(path=&#39;abfss://tfm@tfmgendos.dfs.core.windows.net/silver/&#39;, name=&#39;silver/&#39;, size=0, modificationTime=1662129145000)]</div>

# %%
# autoloader table and checkpoint paths

OCDEDatabaseByCountry_Bronce = basepath + "bronze/ocde/"
bronzeCheckpoint = basepath + "bronze/ocde/checkpoint/"
bronzeSchema = basepath + "bronze/ocde/schema/"

forecastGDPIndicatorsTimesAnnual_Silver = basepath + "silver/ocde/GDPPrice/"
forecastGDPCheckpoint = basepath + "silver/ocde/currentGDP/checkpoint/"
landingZoneLocation = basepath + "landing/ocde/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# autoloader table and checkpoint paths
filesBronze=['GDP_Constant_Price_Annual', 'GDP_Current_Price_Annual', 'GDP_PerCapita_Constant_Prices_Annual', 'GDP_PerCapita_Current_Prices_Annual']
#Generar carpetas de autoloader y checkpoints para cada tipo de fichero
for name in filesBronze:      
        exec(f'bronzeTable_{name} = basepath + "bronze/ocde/" + name')
        exec(f'silverTable_{name} = basepath + "silver/ocde/" + name')
        exec(f'silverCheckpoint_{name} = basepath + "silver/ocde/" + name + "/checkpoint/"')
        exec(f'silverSchema_{name} = basepath + "silver/ocde/" + name + "/schema/"')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for name in filesBronze:
      exec(f'dfBronze_{name}= spark.read.format("delta").load('f'bronzeTable_{name})')
#display(dfBronze)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dfBronze_GDP_Constant_Price_Annual)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LOCATION</th><th>Country</th><th>TRANSACT</th><th>Transaction</th><th>MEASURE</th><th>TIME</th><th>Year</th><th>Unit_Code</th><th>Unit</th><th>PowerCode_Code</th><th>PowerCode</th><th>Reference_Period_Code</th><th>Reference_Period</th><th>Value</th><th>Flag_Codes</th><th>Flags</th><th>_rescued_data</th></tr></thead><tbody><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>1995</td><td>1995</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>596805.276</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>1996</td><td>1996</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>620130.163</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>1997</td><td>1997</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>648743.04</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>1998</td><td>1998</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>680769.375</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>1999</td><td>1999</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>707403.985</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>2000</td><td>2000</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>721823.005</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>2001</td><td>2001</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td><td>2015</td><td>750800.782</td><td>null</td><td>null</td><td>{"Measure":"Constant prices, constant PPPs, OECD base year","_file_path":"abfss://tfm@tfmgendos.dfs.core.windows.net/landing/ocde/GDP_Constant_Price_Annual/be9a5962-f4be-4fa3-9056-a2d636a5f985"}</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>Gross domestic product (expenditure approach)</td><td>VPVOB</td><td>2002</td><td>2002</td><td>USD</td><td>US Dollar</td><td>6</td><td>Millions</td><td>2015</td> ...

# %%
dfBronze_GDP_Constant_Price_Annual.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;LOCATION&#39;,
#  &#39;Country&#39;,
#  &#39;TRANSACT&#39;,
#  &#39;Transaction&#39;,
#  &#39;MEASURE&#39;,
#  &#39;TIME&#39;,
#  &#39;Year&#39;,
#  &#39;Unit_Code&#39;,
#  &#39;Unit&#39;,
#  &#39;PowerCode_Code&#39;,
#  &#39;PowerCode&#39;,
#  &#39;Reference_Period_Code&#39;,
#  &#39;Reference_Period&#39;,
#  &#39;Value&#39;,
#  &#39;Flag_Codes&#39;,
#  &#39;Flags&#39;,
#  &#39;_rescued_data&#39;]</div>

# %%
#Using SQL col() function
from pyspark.sql.functions import col 

for name in filesBronze:
      exec(f'dfSilver_{name}=dfBronze_{name}.drop("_rescued_data", "Flag_Codes","Reference_Period","Reference_Period_Code", "TRANSACT", "Transaction", "Year", "Period", "Unit_Code", "PowerCode_Code", "LOCATION", "FREQUENCY", "SUBJECT")')
#           spark.read.format("delta").load('f'bronzeTable_{name})')


#dfSilver = dfBronze.drop("_rescued_data","Flags","Flag_Codes","Reference_Period","Reference_Period_Code")


#dfSilver = dfSilver.na.drop(subset="Estimates_Start_After")

#dfSilver.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dfSilver_GDP_Constant_Price_Annual)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>MEASURE</th><th>TIME</th><th>Unit</th><th>PowerCode</th><th>Value</th><th>Flags</th></tr></thead><tbody><tr><td>Australia</td><td>VPVOB</td><td>1995</td><td>US Dollar</td><td>Millions</td><td>596805.276</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1996</td><td>US Dollar</td><td>Millions</td><td>620130.163</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1997</td><td>US Dollar</td><td>Millions</td><td>648743.04</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1998</td><td>US Dollar</td><td>Millions</td><td>680769.375</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1999</td><td>US Dollar</td><td>Millions</td><td>707403.985</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2000</td><td>US Dollar</td><td>Millions</td><td>721823.005</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2001</td><td>US Dollar</td><td>Millions</td><td>750800.782</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2002</td><td>US Dollar</td><td>Millions</td><td>774153.128</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2003</td><td>US Dollar</td><td>Millions</td><td>806709.726</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2004</td><td>US Dollar</td><td>Millions</td><td>832204.483</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2005</td><td>US Dollar</td><td>Millions</td><td>854897.812</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2006</td><td>US Dollar</td><td>Millions</td><td>887114.53</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2007</td><td>US Dollar</td><td>Millions</td><td>918846.748</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2008</td><td>US Dollar</td><td>Millions</td><td>936000.074</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2009</td><td>US Dollar</td><td>Millions</td><td>956333.151</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2010</td><td>US Dollar</td><td>Millions</td><td>979952.154</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2011</td><td>US Dollar</td><td>Millions</td><td>1018340.431</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2012</td><td>US Dollar</td><td>Millions</td><td>1044819.44</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2013</td><td>US Dollar</td><td>Millions</td><td>1071597.447</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2014</td><td>US Dollar</td><td>Millions</td><td>1094874.738</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2015</td><td>US Dollar</td><td>Millions</td><td>1124892.295</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2016</td><td>US Dollar</td><td>Millions</td><td>1150719.0</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2017</td><td>US Dollar</td><td>Millions</td><td>1183755.826</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2018</td><td>US Dollar</td><td>Millions</td><td>1208770.356</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2019</td><td>US Dollar</td><td>Millions</td><td>1208723.981</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2020</td><td>US Dollar</td><td>Millions</td><td>1226554.628</td><td>null</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2021</td><td>US Dollar</td><td>Millions</td><td>1284180.064</td><td>Estimated value</td></tr><tr><td>Austria</td><td>VPVOB</td><td>1995</td><td>US Dollar</td><td>Millions</td><td>303032.998</td><td>null</td></tr><tr><td>Austria</td><td>VPVOB</td><td>1996</td><td>US Dollar</td><td>Millions</td><td>310152.861</td><td>null</td></tr><tr><td>Austria</td><td>VPVOB</td><td>1997</td><td>US Dollar</td><td>Millions</td><td>316646.219</td><td>null</td></tr><tr><td>Austria</td><td>VPVOB</td><td>1998</td><td>US Dollar</td><td>Millions</td><td>327986.669</td><td>null</td></tr>< ...

# %%
from pyspark.sql.functions import lit
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfSilver_GDP_Constant_Price_Annual = dfSilver_GDP_Constant_Price_Annual.withColumn("macroeconomicIndicator", lit("GDP Constant Prices USD"))
dfSilver_GDP_Current_Price_Annual = dfSilver_GDP_Current_Price_Annual.withColumn("macroeconomicIndicator", lit("GDP Current Prices USD"))
dfSilver_GDP_PerCapita_Constant_Prices_Annual = dfSilver_GDP_PerCapita_Constant_Prices_Annual.withColumn("macroeconomicIndicator", lit("GDP per capita Constant Prices USD"))
dfSilver_GDP_PerCapita_Current_Prices_Annual = dfSilver_GDP_PerCapita_Current_Prices_Annual.withColumn("macroeconomicIndicator", lit("GDP per capita Current Prices USD"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dfSilver_GDP_PerCapita_Current_Prices_Annual)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>MEASURE</th><th>TIME</th><th>Unit</th><th>PowerCode</th><th>Value</th><th>Flags</th><th>macroeconomicIndicator</th></tr></thead><tbody><tr><td>Australia</td><td>HCPC</td><td>2015</td><td>US Dollar</td><td>Units</td><td>47232.62912</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Australia</td><td>HCPC</td><td>2016</td><td>US Dollar</td><td>Units</td><td>50150.652199</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Australia</td><td>HCPC</td><td>2017</td><td>US Dollar</td><td>Units</td><td>50699.175108</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Australia</td><td>HCPC</td><td>2018</td><td>US Dollar</td><td>Units</td><td>52980.734327</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Australia</td><td>HCPC</td><td>2019</td><td>US Dollar</td><td>Units</td><td>52669.473903</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Australia</td><td>HCPC</td><td>2020</td><td>US Dollar</td><td>Units</td><td>55635.462558</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Australia</td><td>HCPC</td><td>2021</td><td>US Dollar</td><td>Units</td><td>61631.9388</td><td>Estimated value</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2015</td><td>US Dollar</td><td>Units</td><td>49942.056293</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2016</td><td>US Dollar</td><td>Units</td><td>52665.087457</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2017</td><td>US Dollar</td><td>Units</td><td>54188.360666</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2018</td><td>US Dollar</td><td>Units</td><td>56978.264771</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2019</td><td>US Dollar</td><td>Units</td><td>58091.272285</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2020</td><td>US Dollar</td><td>Units</td><td>55686.067736</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Austria</td><td>HCPC</td><td>2021</td><td>US Dollar</td><td>Units</td><td>58395.772207</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2015</td><td>US Dollar</td><td>Units</td><td>46201.685891</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2016</td><td>US Dollar</td><td>Units</td><td>48599.202676</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2017</td><td>US Dollar</td><td>Units</td><td>50442.947518</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2018</td><td>US Dollar</td><td>Units</td><td>52535.511671</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2019</td><td>US Dollar</td><td>Units</td><td>54278.264883</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2020</td><td>US Dollar</td><td>Units</td><td>53071.34083</td><td>Provisional value</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Belgium</td><td>HCPC</td><td>2021</td><td>US Dollar</td><td>Units</td><td>58925.223286</td><td>Provisional value</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Canada</td><td>HCPC</td><td>2015</td><td>US Dollar</td><td>Units</td><td>44670.054374</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Canada</td><td>HCPC</td><td>2016</td><td>US Dollar</td><td>Units</td><td>46472.368771</td><td>null</td><td>GDP per capita Current Prices USD</td></tr><tr><td>Canada</td><td>HCPC< ...

# %%
df1 = dfSilver_GDP_Constant_Price_Annual.union(dfSilver_GDP_Current_Price_Annual)
df2 = df1.union(dfSilver_GDP_PerCapita_Constant_Prices_Annual)
df_final = df2.union(dfSilver_GDP_PerCapita_Current_Prices_Annual)

df_final.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 3733</div>

# %%
display(df_final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>MEASURE</th><th>TIME</th><th>Unit</th><th>PowerCode</th><th>Value</th><th>Flags</th><th>macroeconomicIndicator</th></tr></thead><tbody><tr><td>Australia</td><td>VPVOB</td><td>1995</td><td>US Dollar</td><td>Millions</td><td>596805.276</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1996</td><td>US Dollar</td><td>Millions</td><td>620130.163</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1997</td><td>US Dollar</td><td>Millions</td><td>648743.04</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1998</td><td>US Dollar</td><td>Millions</td><td>680769.375</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1999</td><td>US Dollar</td><td>Millions</td><td>707403.985</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2000</td><td>US Dollar</td><td>Millions</td><td>721823.005</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2001</td><td>US Dollar</td><td>Millions</td><td>750800.782</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2002</td><td>US Dollar</td><td>Millions</td><td>774153.128</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2003</td><td>US Dollar</td><td>Millions</td><td>806709.726</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2004</td><td>US Dollar</td><td>Millions</td><td>832204.483</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2005</td><td>US Dollar</td><td>Millions</td><td>854897.812</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2006</td><td>US Dollar</td><td>Millions</td><td>887114.53</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2007</td><td>US Dollar</td><td>Millions</td><td>918846.748</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2008</td><td>US Dollar</td><td>Millions</td><td>936000.074</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2009</td><td>US Dollar</td><td>Millions</td><td>956333.151</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2010</td><td>US Dollar</td><td>Millions</td><td>979952.154</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2011</td><td>US Dollar</td><td>Millions</td><td>1018340.431</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2012</td><td>US Dollar</td><td>Millions</td><td>1044819.44</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2013</td><td>US Dollar</td><td>Millions</td><td>1071597.447</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2014</td><td>US Dollar</td><td>Millions</td><td>1094874.738</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2015</td><td>US Dollar</td><td>Millions</td><td>1124892.295</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2016</td><td>US Dollar</td><td>Millions</td><td>1150719.0</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2017</td><td>US Dollar</td><td>Millions</td><td>1183755.826</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2018</td><td>US Dollar</td><td>Millions</td><td>1208770.356</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2019</td><td>US ...

# %%
df_final2 = df_final.withColumnRenamed("Country","country_desc") \
    .withColumnRenamed("MEASURE","measure") \
    .withColumnRenamed("TIME","period") \
    .withColumnRenamed("Unit","unitMeasure_code") \
    .withColumnRenamed("PowerCode","typeOfData") \
    .withColumnRenamed("Value","value") \
    .withColumnRenamed("Flags","typeOfValue")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_final2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_desc</th><th>measure</th><th>period</th><th>unitMeasure_code</th><th>typeOfData</th><th>value</th><th>typeOfValue</th><th>macroeconomicIndicator</th></tr></thead><tbody><tr><td>Australia</td><td>VPVOB</td><td>1995</td><td>US Dollar</td><td>Millions</td><td>596805.276</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1996</td><td>US Dollar</td><td>Millions</td><td>620130.163</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1997</td><td>US Dollar</td><td>Millions</td><td>648743.04</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1998</td><td>US Dollar</td><td>Millions</td><td>680769.375</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>1999</td><td>US Dollar</td><td>Millions</td><td>707403.985</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2000</td><td>US Dollar</td><td>Millions</td><td>721823.005</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2001</td><td>US Dollar</td><td>Millions</td><td>750800.782</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2002</td><td>US Dollar</td><td>Millions</td><td>774153.128</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2003</td><td>US Dollar</td><td>Millions</td><td>806709.726</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2004</td><td>US Dollar</td><td>Millions</td><td>832204.483</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2005</td><td>US Dollar</td><td>Millions</td><td>854897.812</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2006</td><td>US Dollar</td><td>Millions</td><td>887114.53</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2007</td><td>US Dollar</td><td>Millions</td><td>918846.748</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2008</td><td>US Dollar</td><td>Millions</td><td>936000.074</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2009</td><td>US Dollar</td><td>Millions</td><td>956333.151</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2010</td><td>US Dollar</td><td>Millions</td><td>979952.154</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2011</td><td>US Dollar</td><td>Millions</td><td>1018340.431</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2012</td><td>US Dollar</td><td>Millions</td><td>1044819.44</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2013</td><td>US Dollar</td><td>Millions</td><td>1071597.447</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2014</td><td>US Dollar</td><td>Millions</td><td>1094874.738</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2015</td><td>US Dollar</td><td>Millions</td><td>1124892.295</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2016</td><td>US Dollar</td><td>Millions</td><td>1150719.0</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2017</td><td>US Dollar</td><td>Millions</td><td>1183755.826</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPVOB</td><td>2018</td><td>US Dollar</td><td>Millions</td><td>1208770.356</td><td>null</td><td>GDP Constant Prices USD</td></tr><tr><td>Australia</td><td>VPV ...

# %%
df_final2.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- country_desc: string (nullable = true)
# -- measure: string (nullable = true)
# -- period: integer (nullable = true)
# -- unitMeasure_code: string (nullable = true)
# -- typeOfData: string (nullable = true)
# -- value: double (nullable = true)
# -- typeOfValue: string (nullable = true)
# -- macroeconomicIndicator: string (nullable = false)
#
# </div>

# %%
df_final3 = df_final2.withColumn("value", col("value").cast("Float"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
actualGDPdIndicatorsAnnual_Silver = basepath + "silver/ocde/" + "actualGDPdIndicatorsAnnual_Silver"
df_final3.write.format('delta').mode('overwrite').save(actualGDPdIndicatorsAnnual_Silver)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test = spark.read.format("delta").load(actualGDPdIndicatorsAnnual_Silver)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: 3733</div>

# %%
#NO PASAR ----------------------

# %%
pdSilver = dfSilver.toPandas()
pdSilver.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LOCATION</th>
#       <th>Country</th>
#       <th>SUBJECT</th>
#       <th>MEASURE</th>
#       <th>FREQUENCY</th>
#       <th>TIME</th>
#       <th>Period</th>
#       <th>Unit_Code</th>
#       <th>Unit</th>
#       <th>PowerCode_Code</th>
#       <th>PowerCode</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AUS</td>
#       <td>Australia</td>
#       <td>B1_GE</td>
#       <td>CQRSA</td>
#       <td>Q</td>
#       <td>1995-Q4</td>
#       <td>Q4-1995</td>
#       <td>AUD</td>
#       <td>Australian Dollar</td>
#       <td>6</td>
#       <td>Millions</td>
#       <td>131406</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AUS</td>
#       <td>Australia</td>
#       <td>B1_GE</td>
#       <td>CQRSA</td>
#       <td>Q</td>
#       <td>1996-Q1</td>
#       <td>Q1-1996</td>
#       <td>AUD</td>
#       <td>Australian Dollar</td>
#       <td>6</td>
#       <td>Millions</td>
#       <td>133106</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AUS</td>
#       <td>Australia</td>
#       <td>B1_GE</td>
#       <td>CQRSA</td>
#       <td>Q</td>
#       <td>1996-Q2</td>
#       <td>Q2-1996</td>
#       <td>AUD</td>
#       <td>Australian Dollar</td>
#       <td>6</td>
#       <td>Millions</td>
#       <td>135186</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AUS</td>
#       <td>Australia</td>
#       <td>B1_GE</td>
#       <td>CQRSA</td>
#       <td>Q</td>
#       <td>1996-Q3</td>
#       <td>Q3-1996</td>
#       <td>AUD</td>
#       <td>Australian Dollar</td>
#       <td>6</td>
#       <td>Millions</td>
#       <td>135918</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>AUS</td>
#       <td>Australia</td>
#       <td>B1_GE</td>
#       <td>CQRSA</td>
#       <td>Q</td>
#       <td>1996-Q4</td>
#       <td>Q4-1996</td>
#       <td>AUD</td>
#       <td>Australian Dollar</td>
#       <td>6</td>
#       <td>Millions</td>
#       <td>137865</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#pdSilver = pdSilver.melt(id_vars=["Country","Subject_Descriptor"
,"Subject_Notes"
,"Units"
,"Scale"
,"Estimates_Start_After"], 
        var_name="period", 
        value_name="value")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-161498123332629&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">5</span>
# <span class="ansi-red-fg">    &#34;Estimates_Start_After&#34;],(&#34;&#34;)</span>
#                            ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> unmatched &#39;]&#39;
# </div>

# %%
import pandas as pd

pdSilver['Estimates_Start_After'] = pdSilver['Estimates_Start_After'].astype('int')
pdSilver['period'] = pdSilver['period'].astype('int')

pdSilver.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">get_loc</span><span class="ansi-blue-fg">(self, key, method, tolerance)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3079</span>             <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 3080</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_engine<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>casted_key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3081</span>             <span class="ansi-green-fg">except</span> KeyError <span class="ansi-green-fg">as</span> err<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">pandas/_libs/index.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.index.IndexEngine.get_loc</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/index.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.index.IndexEngine.get_loc</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/hashtable_class_helper.pxi</span> in <span class="ansi-cyan-fg">pandas._libs.hashtable.PyObjectHashTable.get_item</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/hashtable_class_helper.pxi</span> in <span class="ansi-cyan-fg">pandas._libs.hashtable.PyObjectHashTable.get_item</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;Estimates_Start_After&#39;
#
# The above exception was the direct cause of the following exception:
#
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-161498123332630&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">import</span> pandas <span class="ansi-green-fg">as</span> pd
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;Estimates_Start_After&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;Estimates_Start_After&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>astype<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;int&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;period&#39;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;period&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>astype<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;int&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/frame.py</span> in <span class="ansi-cyan-fg">__getitem__</span><span class="ansi-blue-fg">(self, key)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3022</span>             <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">.</span>nlevels <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   3023</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_getitem_multilevel<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 3024</span><span class="ansi-red-fg">             </span>indexer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3025</span>             <span class="ansi-green-fg">if</span> is_integer<span class="ansi-blue-fg">(</span>indexer<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   3026</span>                 indexer <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>indexer<span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">get_loc</span><span class="ansi-blue-fg">(self, key, method, tolerance)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3080</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_engine<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>casted_key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3081</span>             <span class="ansi-green-fg">except</span> KeyError <span class="ansi-green-fg">as</span> err<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 3082</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> KeyError<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">from</span> err
# <span class="ansi-green-intense-fg ansi-bold">   3083</span>
# <span class="ansi-green-intense-fg ansi-bold">   3084</span>         <span class="ansi-green-fg">if</span> tolerance <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;Estimates_Start_After&#39;</div>

# %%
pdSilver = pdSilver[pdSilver['Estimates_Start_After']< pdSilver['period']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">get_loc</span><span class="ansi-blue-fg">(self, key, method, tolerance)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3079</span>             <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 3080</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_engine<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>casted_key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3081</span>             <span class="ansi-green-fg">except</span> KeyError <span class="ansi-green-fg">as</span> err<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">pandas/_libs/index.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.index.IndexEngine.get_loc</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/index.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.index.IndexEngine.get_loc</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/hashtable_class_helper.pxi</span> in <span class="ansi-cyan-fg">pandas._libs.hashtable.PyObjectHashTable.get_item</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/hashtable_class_helper.pxi</span> in <span class="ansi-cyan-fg">pandas._libs.hashtable.PyObjectHashTable.get_item</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;Estimates_Start_After&#39;
#
# The above exception was the direct cause of the following exception:
#
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-161498123332631&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>pdSilver <span class="ansi-blue-fg">=</span> pdSilver<span class="ansi-blue-fg">[</span>pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;Estimates_Start_After&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">&lt;</span> pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;period&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/frame.py</span> in <span class="ansi-cyan-fg">__getitem__</span><span class="ansi-blue-fg">(self, key)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3022</span>             <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">.</span>nlevels <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   3023</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_getitem_multilevel<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 3024</span><span class="ansi-red-fg">             </span>indexer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3025</span>             <span class="ansi-green-fg">if</span> is_integer<span class="ansi-blue-fg">(</span>indexer<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   3026</span>                 indexer <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>indexer<span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">get_loc</span><span class="ansi-blue-fg">(self, key, method, tolerance)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3080</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_engine<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>casted_key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3081</span>             <span class="ansi-green-fg">except</span> KeyError <span class="ansi-green-fg">as</span> err<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 3082</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> KeyError<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">from</span> err
# <span class="ansi-green-intense-fg ansi-bold">   3083</span>
# <span class="ansi-green-intense-fg ansi-bold">   3084</span>         <span class="ansi-green-fg">if</span> tolerance <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;Estimates_Start_After&#39;</div>

# %%
pdSilver[(pdSilver.Country=="Spain") & (pdSilver.Scale == "Billions")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-161498123332632&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">(</span>pdSilver<span class="ansi-blue-fg">.</span>Country<span class="ansi-blue-fg">==</span><span class="ansi-blue-fg">&#34;Spain&#34;</span><span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">&amp;</span> <span class="ansi-blue-fg">(</span>pdSilver<span class="ansi-blue-fg">.</span>Scale <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#34;Billions&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/generic.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">   5463</span>             <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>_info_axis<span class="ansi-blue-fg">.</span>_can_hold_identifiers_and_holds_name<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   5464</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">[</span>name<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-fg">-&gt; 5465</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> object<span class="ansi-blue-fg">.</span>__getattribute__<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   5466</span>
# <span class="ansi-green-intense-fg ansi-bold">   5467</span>     <span class="ansi-green-fg">def</span> __setattr__<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> name<span class="ansi-blue-fg">:</span> str<span class="ansi-blue-fg">,</span> value<span class="ansi-blue-fg">)</span> <span class="ansi-blue-fg">-&gt;</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;DataFrame&#39; object has no attribute &#39;Scale&#39;</div>

# %%
pdSilver.drop('Estimates_Start_After', axis=1, inplace=True)

pdSilver.rename(columns={'Country': 'country_desc', 'Subject_Descriptor': 'subject_descriptor','Subject_Notes': 'subject_detail', 'Units': 'unitMeasure_code', 'Scale': 'unit'}, inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-161498123332633&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>pdSilver<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Estimates_Start_After&#39;</span><span class="ansi-blue-fg">,</span> axis<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span> inplace<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> pdSilver<span class="ansi-blue-fg">.</span>rename<span class="ansi-blue-fg">(</span>columns<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">{</span><span class="ansi-blue-fg">&#39;Country&#39;</span><span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;country_desc&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;Subject_Descriptor&#39;</span><span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;subject_descriptor&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;Subject_Notes&#39;</span><span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;subject_detail&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;Units&#39;</span><span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;unitMeasure_code&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;Scale&#39;</span><span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;unit&#39;</span><span class="ansi-blue-fg">}</span><span class="ansi-blue-fg">,</span> inplace<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/frame.py</span> in <span class="ansi-cyan-fg">drop</span><span class="ansi-blue-fg">(self, labels, axis, index, columns, level, inplace, errors)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4306</span>                 weight  <span class="ansi-cyan-fg">1.0</span>     <span class="ansi-cyan-fg">0.8</span>
# <span class="ansi-green-intense-fg ansi-bold">   4307</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">-&gt; 4308</span><span class="ansi-red-fg">         return super().drop(
# </span><span class="ansi-green-intense-fg ansi-bold">   4309</span>             labels<span class="ansi-blue-fg">=</span>labels<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">   4310</span>             axis<span class="ansi-blue-fg">=</span>axis<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/generic.py</span> in <span class="ansi-cyan-fg">drop</span><span class="ansi-blue-fg">(self, labels, axis, index, columns, level, inplace, errors)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4151</span>         <span class="ansi-green-fg">for</span> axis<span class="ansi-blue-fg">,</span> labels <span class="ansi-green-fg">in</span> axes<span class="ansi-blue-fg">.</span>items<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   4152</span>             <span class="ansi-green-fg">if</span> labels <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 4153</span><span class="ansi-red-fg">                 </span>obj <span class="ansi-blue-fg">=</span> obj<span class="ansi-blue-fg">.</span>_drop_axis<span class="ansi-blue-fg">(</span>labels<span class="ansi-blue-fg">,</span> axis<span class="ansi-blue-fg">,</span> level<span class="ansi-blue-fg">=</span>level<span class="ansi-blue-fg">,</span> errors<span class="ansi-blue-fg">=</span>errors<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4154</span>
# <span class="ansi-green-intense-fg ansi-bold">   4155</span>         <span class="ansi-green-fg">if</span> inplace<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/generic.py</span> in <span class="ansi-cyan-fg">_drop_axis</span><span class="ansi-blue-fg">(self, labels, axis, level, errors)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4186</span>                 new_axis <span class="ansi-blue-fg">=</span> axis<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span>labels<span class="ansi-blue-fg">,</span> level<span class="ansi-blue-fg">=</span>level<span class="ansi-blue-fg">,</span> errors<span class="ansi-blue-fg">=</span>errors<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4187</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 4188</span><span class="ansi-red-fg">                 </span>new_axis <span class="ansi-blue-fg">=</span> axis<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span>labels<span class="ansi-blue-fg">,</span> errors<span class="ansi-blue-fg">=</span>errors<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4189</span>             result <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>reindex<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">**</span><span class="ansi-blue-fg">{</span>axis_name<span class="ansi-blue-fg">:</span> new_axis<span class="ansi-blue-fg">}</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   4190</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">drop</span><span class="ansi-blue-fg">(self, labels, errors)</span>
# <span class="ansi-green-intense-fg ansi-bold">   5589</span>         <span class="ansi-green-fg">if</span> mask<span class="ansi-blue-fg">.</span>any<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   5590</span>             <span class="ansi-green-fg">if</span> errors <span class="ansi-blue-fg">!=</span> <span class="ansi-blue-fg">&#34;ignore&#34;</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 5591</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> KeyError<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#34;{labels[mask]} not found in axis&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   5592</span>             indexer <span class="ansi-blue-fg">=</span> indexer<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">~</span>mask<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">   5593</span>         <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>delete<span class="ansi-blue-fg">(</span>indexer<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-

# %%
pdSilver.reset_index(drop=True, inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(pdSilver.count())
pdSilver.tail()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">LOCATION          102927
# Country           102927
# SUBJECT           102927
# MEASURE           102927
# FREQUENCY         102927
# TIME              102927
# Period             99101
# Unit_Code         102927
# Unit              102927
# PowerCode_Code    102927
# PowerCode         102927
# Value             102927
# dtype: int64
# Out[21]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LOCATION</th>
#       <th>Country</th>
#       <th>SUBJECT</th>
#       <th>MEASURE</th>
#       <th>FREQUENCY</th>
#       <th>TIME</th>
#       <th>Period</th>
#       <th>Unit_Code</th>
#       <th>Unit</th>
#       <th>PowerCode_Code</th>
#       <th>PowerCode</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>102922</th>
#       <td>EA19</td>
#       <td>Euro area (19 countries)</td>
#       <td>NAEXKP01</td>
#       <td>STSA</td>
#       <td>Q</td>
#       <td>2021-Q2</td>
#       <td>None</td>
#       <td>EUR</td>
#       <td>Euro</td>
#       <td>9</td>
#       <td>Billions</td>
#       <td>2421.785122433</td>
#     </tr>
#     <tr>
#       <th>102923</th>
#       <td>EA19</td>
#       <td>Euro area (19 countries)</td>
#       <td>NAEXKP01</td>
#       <td>STSA</td>
#       <td>Q</td>
#       <td>2021-Q3</td>
#       <td>None</td>
#       <td>EUR</td>
#       <td>Euro</td>
#       <td>9</td>
#       <td>Billions</td>
#       <td>2474.3728076589</td>
#     </tr>
#     <tr>
#       <th>102924</th>
#       <td>EA19</td>
#       <td>Euro area (19 countries)</td>
#       <td>NAEXKP01</td>
#       <td>STSA</td>
#       <td>Q</td>
#       <td>2021-Q4</td>
#       <td>None</td>
#       <td>EUR</td>
#       <td>Euro</td>
#       <td>9</td>
#       <td>Billions</td>
#       <td>2486.4001982031</td>
#     </tr>
#     <tr>
#       <th>102925</th>
#       <td>EA19</td>
#       <td>Euro area (19 countries)</td>
#       <td>NAEXKP01</td>
#       <td>STSA</td>
#       <td>Q</td>
#       <td>2022-Q1</td>
#       <td>None</td>
#       <td>EUR</td>
#       <td>Euro</td>
#       <td>9</td>
#       <td>Billions</td>
#       <td>2502.9558725927</td>
#     </tr>
#     <tr>
#       <th>102926</th>
#       <td>EA19</td>
#       <td>Euro area (19 countries)</td>
#       <td>NAEXKP01</td>
#       <td>STSA</td>
#       <td>Q</td>
#       <td>2022-Q2</td>
#       <td>None</td>
#       <td>EUR</td>
#       <td>Euro</td>
#       <td>9</td>
#       <td>Billions</td>
#       <td>2522.2650383599</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pdSilver["macroeconomicIndicator"] = pdSilver["subject_detail"].map(lambda x: 'GDP Current Prices USD' if x.startswith('Values are based upon GDP') else 'GDP per capita Current Prices USD')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">get_loc</span><span class="ansi-blue-fg">(self, key, method, tolerance)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3079</span>             <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 3080</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_engine<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>casted_key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3081</span>             <span class="ansi-green-fg">except</span> KeyError <span class="ansi-green-fg">as</span> err<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">pandas/_libs/index.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.index.IndexEngine.get_loc</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/index.pyx</span> in <span class="ansi-cyan-fg">pandas._libs.index.IndexEngine.get_loc</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/hashtable_class_helper.pxi</span> in <span class="ansi-cyan-fg">pandas._libs.hashtable.PyObjectHashTable.get_item</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-green-fg">pandas/_libs/hashtable_class_helper.pxi</span> in <span class="ansi-cyan-fg">pandas._libs.hashtable.PyObjectHashTable.get_item</span><span class="ansi-blue-fg">()</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;subject_detail&#39;
#
# The above exception was the direct cause of the following exception:
#
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-161498123332636&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#34;macroeconomicIndicator&#34;</span><span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> pdSilver<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#34;subject_detail&#34;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>map<span class="ansi-blue-fg">(</span><span class="ansi-green-fg">lambda</span> x<span class="ansi-blue-fg">:</span> <span class="ansi-blue-fg">&#39;GDP Current Prices USD&#39;</span> <span class="ansi-green-fg">if</span> x<span class="ansi-blue-fg">.</span>startswith<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Values are based upon GDP&#39;</span><span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">else</span> <span class="ansi-blue-fg">&#39;GDP per capita Current Prices USD&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/frame.py</span> in <span class="ansi-cyan-fg">__getitem__</span><span class="ansi-blue-fg">(self, key)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3022</span>             <span class="ansi-green-fg">if</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">.</span>nlevels <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   3023</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_getitem_multilevel<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 3024</span><span class="ansi-red-fg">             </span>indexer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3025</span>             <span class="ansi-green-fg">if</span> is_integer<span class="ansi-blue-fg">(</span>indexer<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   3026</span>                 indexer <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>indexer<span class="ansi-blue-fg">]</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/pandas/core/indexes/base.py</span> in <span class="ansi-cyan-fg">get_loc</span><span class="ansi-blue-fg">(self, key, method, tolerance)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3080</span>                 <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_engine<span class="ansi-blue-fg">.</span>get_loc<span class="ansi-blue-fg">(</span>casted_key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   3081</span>             <span class="ansi-green-fg">except</span> KeyError <span class="ansi-green-fg">as</span> err<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 3082</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> KeyError<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">from</span> err
# <span class="ansi-green-intense-fg ansi-bold">   3083</span>
# <span class="ansi-green-intense-fg ansi-bold">   3084</span>         <span class="ansi-green-fg">if</span> tolerance <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">KeyError</span>: &#39;subject_detail&#39;</div>

# %%
display(pdSilver)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LOCATION</th><th>Country</th><th>SUBJECT</th><th>MEASURE</th><th>FREQUENCY</th><th>TIME</th><th>Period</th><th>Unit_Code</th><th>Unit</th><th>PowerCode_Code</th><th>PowerCode</th><th>Value</th></tr></thead><tbody><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1995-Q4</td><td>Q4-1995</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>131406</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1996-Q1</td><td>Q1-1996</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>133106</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1996-Q2</td><td>Q2-1996</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>135186</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1996-Q3</td><td>Q3-1996</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>135918</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1996-Q4</td><td>Q4-1996</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>137865</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1997-Q1</td><td>Q1-1997</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>139099</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1997-Q2</td><td>Q2-1997</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>142625</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1997-Q3</td><td>Q3-1997</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>143608</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1997-Q4</td><td>Q4-1997</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>147428</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1998-Q1</td><td>Q1-1998</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>148455</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1998-Q2</td><td>Q2-1998</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>149648</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1998-Q3</td><td>Q3-1998</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>152295</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1998-Q4</td><td>Q4-1998</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>155137</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1999-Q1</td><td>Q1-1999</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>156530</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1999-Q2</td><td>Q2-1999</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>157437</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1999-Q3</td><td>Q3-1999</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>160402</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1999-Q4</td><td>Q4-1999</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>163220</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2000-Q1</td><td>Q1-2000</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>168180</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2000-Q2</td><td>Q2-2000</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>170218</td></tr><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2 ...

# %%
dfSilver = spark.createDataFrame(pdSilver)

dfSilver.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- LOCATION: string (nullable = true)
# -- Country: string (nullable = true)
# -- SUBJECT: string (nullable = true)
# -- MEASURE: string (nullable = true)
# -- FREQUENCY: string (nullable = true)
# -- TIME: string (nullable = true)
# -- Period: string (nullable = true)
# -- Unit_Code: string (nullable = true)
# -- Unit: string (nullable = true)
# -- PowerCode_Code: string (nullable = true)
# -- PowerCode: string (nullable = true)
# -- Value: string (nullable = true)
#
# </div>

# %%
dfSilver = dfSilver.dropDuplicates()

dfSilver.show()
dfSilver.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+---------+-------+-------+---------+-------+-------+---------+-----------------+--------------+---------+------+
# LOCATION|  Country|SUBJECT|MEASURE|FREQUENCY|   TIME| Period|Unit_Code|             Unit|PowerCode_Code|PowerCode| Value|
# +--------+---------+-------+-------+---------+-------+-------+---------+-----------------+--------------+---------+------+
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1997-Q3|Q3-1997|      AUD|Australian Dollar|             6| Millions|143608|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|2000-Q3|Q3-2000|      AUD|Australian Dollar|             6| Millions|174444|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1999-Q1|Q1-1999|      AUD|Australian Dollar|             6| Millions|156530|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1997-Q2|Q2-1997|      AUD|Australian Dollar|             6| Millions|142625|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1996-Q2|Q2-1996|      AUD|Australian Dollar|             6| Millions|135186|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1999-Q2|Q2-1999|      AUD|Australian Dollar|             6| Millions|157437|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1996-Q3|Q3-1996|      AUD|Australian Dollar|             6| Millions|135918|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1997-Q1|Q1-1997|      AUD|Australian Dollar|             6| Millions|139099|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1996-Q1|Q1-1996|      AUD|Australian Dollar|             6| Millions|133106|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|2000-Q4|Q4-2000|      AUD|Australian Dollar|             6| Millions|173507|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1998-Q1|Q1-1998|      AUD|Australian Dollar|             6| Millions|148455|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|2000-Q1|Q1-2000|      AUD|Australian Dollar|             6| Millions|168180|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|2000-Q2|Q2-2000|      AUD|Australian Dollar|             6| Millions|170218|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1998-Q2|Q2-1998|      AUD|Australian Dollar|             6| Millions|149648|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1998-Q3|Q3-1998|      AUD|Australian Dollar|             6| Millions|152295|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1996-Q4|Q4-1996|      AUD|Australian Dollar|             6| Millions|137865|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1998-Q4|Q4-1998|      AUD|Australian Dollar|             6| Millions|155137|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1995-Q4|Q4-1995|      AUD|Australian Dollar|             6| Millions|131406|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1999-Q4|Q4-1999|      AUD|Australian Dollar|             6| Millions|163220|
#      AUS|Australia|  B1_GE|  CQRSA|        Q|1997-Q4|Q4-1997|      AUD|Australian Dollar|             6| Millions|147428|
# +--------+---------+-------+-------+---------+-------+-------+---------+-----------------+--------------+---------+------+
# only showing top 20 rows
#
# Out[25]: 102927</div>

# %%
dfSilver.write.format('delta').mode('overwrite').save(forecastGDPIndicatorsTimesAnnual_Silver)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
forecastGDP = spark.read.format("delta").load(forecastGDPIndicatorsTimesAnnual_Silver)

display(forecastGDP)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LOCATION</th><th>Country</th><th>SUBJECT</th><th>MEASURE</th><th>FREQUENCY</th><th>TIME</th><th>Period</th><th>Unit_Code</th><th>Unit</th><th>PowerCode_Code</th><th>PowerCode</th><th>Value</th></tr></thead><tbody><tr><td>AUS</td><td>Australia</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1997-Q3</td><td>Q3-1997</td><td>AUD</td><td>Australian Dollar</td><td>6</td><td>Millions</td><td>143608</td></tr><tr><td>CAN</td><td>Canada</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2021-Q2</td><td>Q2-2021</td><td>CAD</td><td>Canadian Dollar</td><td>6</td><td>Millions</td><td>612204</td></tr><tr><td>FIN</td><td>Finland</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2007-Q1</td><td>Q1-2007</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>45395</td></tr><tr><td>FRA</td><td>France</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2015-Q2</td><td>Q2-2015</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>548304.5</td></tr><tr><td>DEU</td><td>Germany</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2014-Q4</td><td>Q4-2014</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>741994</td></tr><tr><td>DEU</td><td>Germany</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2018-Q2</td><td>Q2-2018</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>843116</td></tr><tr><td>HUN</td><td>Hungary</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1998-Q2</td><td>Q2-1998</td><td>HUF</td><td>Forint</td><td>6</td><td>Millions</td><td>2556194</td></tr><tr><td>IRL</td><td>Ireland</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>1996-Q3</td><td>Q3-1996</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>15112.4</td></tr><tr><td>JPN</td><td>Japan</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2013-Q1</td><td>Q1-2013</td><td>JPY</td><td>Yen</td><td>6</td><td>Millions</td><td>125747950</td></tr><tr><td>KOR</td><td>Korea</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2011-Q2</td><td>Q2-2011</td><td>KRW</td><td>Won</td><td>6</td><td>Millions</td><td>343885900</td></tr><tr><td>NLD</td><td>Netherlands</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2020-Q3</td><td>Q3-2020</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>201329.7</td></tr><tr><td>PRT</td><td>Portugal</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2011-Q4</td><td>Q4-2011</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>43153.8</td></tr><tr><td>SWE</td><td>Sweden</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2003-Q3</td><td>Q3-2003</td><td>SEK</td><td>Swedish Krona</td><td>6</td><td>Millions</td><td>681459</td></tr><tr><td>SWE</td><td>Sweden</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2006-Q1</td><td>Q1-2006</td><td>SEK</td><td>Swedish Krona</td><td>6</td><td>Millions</td><td>760699</td></tr><tr><td>SWE</td><td>Sweden</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2016-Q3</td><td>Q3-2016</td><td>SEK</td><td>Swedish Krona</td><td>6</td><td>Millions</td><td>1102814</td></tr><tr><td>CHE</td><td>Switzerland</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2008-Q3</td><td>Q3-2008</td><td>CHF</td><td>Swiss Franc</td><td>6</td><td>Millions</td><td>155369.1</td></tr><tr><td>TUR</td><td>Türkiye</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2000-Q1</td><td>Q1-2000</td><td>TRY</td><td>Turkish Lira</td><td>6</td><td>Millions</td><td>38021.5</td></tr><tr><td>ISR</td><td>Israel</td><td>B1_GE</td><td>CQRSA</td><td>Q</td><td>2015-Q2</td><td>Q2-2015</td><td>ILS</td><td>New Israeli Sheqel</td><td>6</td><td>Millions</td><td>293975</td></tr><tr><td>AUT</td><td>Austria</td><td>P3</td><td>CQRSA</td><td>Q</td><td>2019-Q2</td><td>Q2-2019</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>70290.5</td></tr><tr><td>BEL</td><td>Belgium</td><td>P3</td><td>CQRSA</td><td>Q</td><td>2002-Q1</td><td>Q1-2002</td><td>EUR</td><td>Euro</td><td>6</td><td>Millions</td><td>49642</td></tr><tr><td>FIN</td><td>Finland</td><td>P3</td><td>CQRSA</td><td>Q</td><td>2021-Q4</td><td>Q4-2021</t ...
